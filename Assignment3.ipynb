# %%
#input
slides = int(input("Enter number of slides: "))

if slides == 3:
    print("the shape is a triangel")

elif slides == 4:
    length = float(input("Enter length: "))
    width = float(input("Enter width: "))

    if length == width:
        print("The shape is a square")
    else:
        print("The shape is a rectangle")

else:
        print("Uknown shape")
